# %%
from ultralytics import RTDETR
import albumentations as A

model = RTDETR("rtdetr-x.pt")

# %%
# 1. Define your custom augmentation pipeline
# We use A.OneOf to make it happen sometimes, not always

# custom_transforms = [
#     A.RandomBrightnessContrast(p=0.5), # Adjust brightness/contrast
#     A.HorizontalFlip(p=0.5),           # Apply horizontal flip
#     A.Blur(blur_limit=3, p=0.3),       # Apply a slight blur
#     A.Rotate(limit=20, p=0.3),          # Apply rotation
#     A.MotionBlur(p=0.2),
# ]
A.MotionBlur(p=0.2),
A.Rotate(limit=20, p=0.3),          # Apply rotation
# Out:
# (Rotate(always_apply=False, p=0.3, limit=(-20, 20), interpolation=1, border_mode=4, value=None, mask_value=None, rotate_method='largest_box', crop_border=False),)

# %%
results = model.train(
    data="ycbcr_AFDET_dataset.yaml",
    epochs=70,
    imgsz=640,
    batch=8,
    patience=10,
    name="rtdetr_x_ycbcr"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.8 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.7 🚀 Python-3.11.9 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12029MiB)
# ...

# %%
results
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fbcfc352910>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
# ...
